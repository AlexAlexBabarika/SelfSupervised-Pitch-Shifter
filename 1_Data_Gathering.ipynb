# %%
from datasets import load_dataset
import os
from dotenv import load_dotenv

# %%
load_dotenv()
HF_TOKEN = os.getenv('HF_TOKEN')
print(HF_TOKEN)

# %%
dataset = load_dataset('confit/nsynth-parquet', 'instrument', split='train', streaming=True, token=HF_TOKEN)
print(next(iter(dataset)))
